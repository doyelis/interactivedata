# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# From the full list of examples provided, I would like to learn how to create Boxplots. I think this kind of representation is useful to show statistical data. For example, as a teacher if I had test score data for a class, I could get insights such as the median score, the spread of the scores and the skewness of the dataset.

# %%
exdata=pd.read_csv('cces_example_data.csv')
exdata.head(10)
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
# 5             4            6    1     3         2   87           9     3
# 6             2            3    1     6         1   83          11     3
# 7             1            1    1     5         1   69          11     3
# 8             1            2    1     6         1   84          10     3
# 9             3            4    2     4         1   63           8     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# ...

# %%
exdata.keys()
# Out:
# Index(['pew_religimp', 'pew_churatd', 'sex', 'educ', 'nonwhite', 'age',
#        'faminc_new', 'pid3', 'ideo5', 'QueerPhobia', 'ImmiPhobia',
#        'InterGBiasParty', 'InterGBiasCand', 'InterGBiasSup', 'LibMediaUse',
#        'ConMediaUse', 'Real_Threat', 'Symb_Threat', 'Evaluation', 'teamweight',
#        'caseid'],
#       dtype='object')

# %% [markdown]
# I could not find 'ImmiPhobia' in the dataframe, most probably because the dataframe is not showing more than 20 columns. To confirm it is there, I looked up for the keys

# %%
fig1, ax1=plt.subplots(1,2)

ax1[0].set_title('Age Histogram')

ax1[1].set_title('Political Identity')


plt.show()

# %%
Evalcount= exdata.groupby('Evaluation')['Evaluation'].count()

fig5, ax5=plt.subplots()
ax5.bar(x=Evalcount.index, height= Evalcount)
ax5.set_xlabel('Evaluation')
ax5.set_ylabel('Evaluation count')

plt.show()

# %% [markdown]
# I have grouped 'Evaluation' by each catagoriacal value and counted how many records have that catagorical value.
# The insight I can draw from here, the most frequent evaluation value in the dataset is 0 followed by 2

# %%
fig3, ax3= plt.subplots()
ax3.scatter(x = exdata['ConMediaUse'], y = exdata['ImmiPhobia'])
ax3.set_xlabel('ConMediaUse')
ax3.set_ylabel('ImmiPhobia')
plt.show()

# %%
fig4, ax4= plt.subplots()
ax4.scatter(x = exdata['ImmiPhobia'], y = exdata['ConMediaUse'])
ax4.set_ylabel('ConMediaUse')
ax4.set_xlabel('ImmiPhobia')

plt.show()

# %% [markdown]
# I wanted to see how the plot would look if we interchange the x and y axis, to review whether this orientation is easier to get insights from
